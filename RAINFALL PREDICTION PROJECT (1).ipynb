# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("austin_weather.csv")
data
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     21-12-2013         74        60        45            67           49
# 1     22-12-2013         56        48        39            43           36
# 2     23-12-2013         58        45        32            31           27
# 3     24-12-2013         61        46        31            36           28
# 4     25-12-2013         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  27-07-2017        103        89        75            71           67
# 1315  28-07-2017        105        91        76            71           64
# 1316  29-07-2017        107        92        77            72           64
# 1317  30-07-2017        106        93        79            70           68
# 1318  31-07-2017         99        88        77            66           61
#
# ...

# %%
cols_to_drop = ["Events", "Date", "SeaLevelPressureLowInche"]
data = data.drop(columns=[c for c in cols_to_drop if c in data.columns])

# %%
data = data.replace('T',0.0)

# %%
data = data.replace('-',0.0)

# %%
data
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
data.to_csv("austin_weather.final.csv")

# %%
import numpy as np
import pandas as pd
import sklearn as sk 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("austin_weather.final.csv")
data
# Out:
#       Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45           67.0          49.0
# 1              1         56        48        39           43.0          36.0
# 2              2         58        45        32           31.0          27.0
# 3              3         61        46        31           36.0          28.0
# 4              4         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314        1314        103        89        75           71.0          67.0
# 1315        1315        105        91        76           71.0          64.0
# 1316        1316        107        92        77           72.0          64.0
# 1317        1317        106        93        79           70.0          68.0
# 1318        1318         99        88        77           66.0          61.0
#
# ...

# %%
X = data.drop(['PrecipitationSumInches'], axis = 1)

# %%
Y = data["PrecipitationSumInches"]

# %%
Y = Y.values.reshape(-1,1)

# %%
day_index = 798
days = [ i  for i in range(Y.size)]

# %%
clf = LinearRegression()
clf.fit(X,Y)
# Out:
# LinearRegression()

# %%
print("The precipitation trend graph:")
plt.scatter(days, Y, color='g')
plt.scatter(days[day_index], Y[day_index], color = 'r')
plt.title("Precipitation level")
plt.xlabel("Days")
plt.ylabel("Precipitation in inches")
x_vis = X.filter(['TempAvgF', 'DewPointAvgF', 'HumidityAvgPercent', 'SeaLevelPressureAvgInches', ' VisibilityAvgMiles', 'WindAvgMPH'])
plt.show()
# Out:
# The precipitation trend graph:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load and clean the data
data = pd.read_csv("austin_weather.final.csv")

# Drop unnecessary columns if they exist
cols_to_drop = ["Events", "Date", "SeaLevelPressureLowInche"]
data = data.drop(columns=[c for c in cols_to_drop if c in data.columns], errors='ignore')

# Replace 'T' and '-' with 0.0
data = data.replace('T', 0.0)
data = data.replace('-', 0.0)

# Convert everything to numeric (in case any column has object dtype after replacements)
data = data.apply(pd.to_numeric, errors='coerce')

# Drop rows with missing values
data = data.dropna()

# Define features and target
X = data.drop(['PrecipitationSumInches'], axis=1)
Y = data["PrecipitationSumInches"].values.reshape(-1, 1)

# Fit the regression model
clf = LinearRegression()
clf.fit(X, Y)

# Define days and day_index for plotting
days = list(range(Y.size))
day_index = [798]  # You can change this as needed

# Plot precipitation trend
print("The precipitation trend graph:")
plt.figure(figsize=(8, 4))
plt.scatter(days, Y, color='g')
plt.scatter(day_index, Y[day_index], color='r')
plt.title("Precipitation level")
plt.xlabel("Days")
plt.ylabel("Precipitation in inches")
plt.show()

# Select attributes to visualize
x_vis = X.filter([
    'TempAvgF', 'DewPointAvgF', 'HumidityAvgPercent',
    'SeaLevelPressureAvgInches', 'VisibilityAvgMiles', 'WindAvgMPH'
])

# Plot 6 attributes in 3x2 grid
print("Precipitation vs. attribute trends:")

fig = plt.figure(figsize=(12, 10))

for i, col in enumerate(x_vis.columns):
    plt.subplot(3, 2, i + 1)
    plt.scatter(days, x_vis[col], color='g', alpha=0.6)
    plt.scatter(day_index, x_vis[col].iloc[day_index], color='r')
    plt.title(col)

plt.tight_layout()
plt.show()
# Out:
# The precipitation trend graph:
# Precipitation vs. attribute trends:
